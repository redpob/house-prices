# %%
import pandas as pd
import numpy as np
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
numerical_cols = list(train.describe().columns)
train[numerical_cols]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
x = train[train.describe().columns].drop('SalePrice', axis = 1).drop([
    'Id', 'MSSubClass', 'OverallCond', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', 
    'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 
    'MoSold', 'YrSold'], axis = 1)
y = train['SalePrice']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corrmat = train.corr()
plt.subplots(figsize = (12,9))
sns.heatmap(corrmat, square = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### GarageArea GarageCars, GarageYrBlt YearBuilt, TotRmsAbvGrd GrLivArea, 1stFlrSF TotalBsmtSF, GrLivArea, 2ndFlrSF, BsmtFullBath BsmtFinSF1, FullBath GrLivArea, TotRmsAbvGrd 2ndFlrSF, GarageYrBlt YearRemodAdd, HalfBath 2ndFlrSF

# %% [markdown]
# ### Id, MSSubClass, OverallCond, BsmtFinSF2, LowQualFinSF, BsmtHalfBath, KitchenAbvGr, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold

# %%
pd.set_option('display.max_columns', None)

# %%
categorical_columns = train.drop(train.describe().columns, axis = 1)
for col in categorical_columns.columns: 
    fig = plt.figure(figsize = (10, 6))
    sns.boxplot(x = col, y = 'SalePrice', data = train)
# Out:
# <ipython-input-9-a34b4381ba1e>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (10, 6))

# %%
dummy_all = pd.DataFrame()
for col in categorical_columns.columns: 
    dummy = pd.get_dummies(train[col], prefix = col)
    if dummy_all.empty: 
        dummy_all = dummy
    else: 
        dummy_all = dummy_all.merge(dummy, how = 'outer', left_index = True, right_index = True)
new_train = dummy_all.merge(train[numerical_cols], how = 'outer', left_index = True, right_index = True)
x = new_train.drop('SalePrice', axis = 1).drop([
    'Id', 'MSSubClass', 'OverallCond', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', 
    'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 
    'MoSold', 'YrSold'], axis = 1)
y = new_train['SalePrice']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn import metrics
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error
XGB = XGBRegressor(n_estimators = 200)
XGB.fit(x_train, y_train)
pred_train = XGB.predict(x_train)
pred_test = XGB.predict(x_test)
print(mean_squared_error(y_train, pred_train))
print(mean_squared_error(y_test, pred_test))
# Out:
# 29532.4665454969
# 696795414.375783

# %%
plt.scatter(y_test, pred_test)
plt.show()

# %%
dummy_all_test = pd.DataFrame()
for col in categorical_columns.columns: 
    dummy = pd.get_dummies(test[col], prefix = col)
    if dummy_all_test.empty: 
        dummy_all_test = dummy
    else: 
        dummy_all_test = dummy_all_test.merge(dummy, how = 'outer', left_index = True, right_index = True)

# %%
train_dummies = list(dummy_all.columns)
test_dummies = list(dummy_all_test.columns)
missing_dummies = np.setdiff1d(train_dummies, test_dummies)
for dummy in missing_dummies: 
    dummy_all_test[dummy] = 0
dummy_all_test = dummy_all_test[list(dummy_all.columns)]

# %%
new_test = dummy_all_test.merge(test[numerical_cols.drop('SalePrice')], how = 'outer', left_index = True, right_index = True)
real_test_x = new_test.drop([
    'Id', 'MSSubClass', 'OverallCond', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath', 
    'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 
    'MoSold', 'YrSold'], axis = 1)

real_test_y = XGB.predict(real_test_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0232b97da777> in <module>
# ----> 1 new_test = dummy_all_test.merge(test[numerical_cols.drop('SalePrice')], how = 'outer', left_index = True, right_index = True)
#       2 asdf = [
#       3     'Id', 'MSSubClass', 'OverallCond', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath',
#       4     'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#       5     'MoSold', 'YrSold']
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
test['SalePrice'] = real_test_y
test.to_csv('Oliver.csv', columns = ['Id', 'SalePrice'], index = False)
#print("Lowest RMSE: ", (-XGB.best_score_)**(1/2.0))
